# %%
from manga_ocr import MangaOcr
import PIL.Image

ocr = MangaOcr()
image_path = "opm_raw.png"
# Out:
# 2026-02-09 18:17:10.686 | INFO     | manga_ocr.ocr:__init__:16 - Loading OCR model from kha-white/manga-ocr-base
# 2026-02-09 18:17:13.393 | INFO     | manga_ocr.ocr:__init__:28 - Using CPU
# 2026-02-09 18:17:13.744 | INFO     | manga_ocr.ocr:__init__:35 - OCR ready

# %%
from inference import model2annotations

img_dir = r'data/examples'
model_path = r'data/comictextdetector.pt'
img_dir = r'data/examples'                              # can be dir list
save_dir = r'data/examples/annotations'
model2annotations(model_path, img_dir, save_dir, save_json=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 7
#       5 img_dir = r'data/examples'                              # can be dir list
#       6 save_dir = r'data/examples/annotations'
# ----> 7 model2annotations(model_path, img_dir, save_dir, save_json=False)
#
# File f:\Code\2026\OCReader\inference.py:24, in model2annotations(model_path, img_dir_list, save_dir, save_json)
#      22 cuda = torch.cuda.is_available()
#      23 device = 'cuda' if cuda else 'cpu'
# ---> 24 model = TextDetector(model_path=model_path, input_size=1024, device=device, act='leaky')
#      25 imglist = []
#      26 for img_dir in img_dir_list:
#
# File f:\Code\2026\OCReader\inference.py:129, in TextDetector.__init__(self, model_path, input_size, device, half, nms_thresh, conf_thresh, mask_thresh, act)
#     127     self.backend = 'opencv'
#     128 else:
# --> 129     self.net = TextDetBase(model_path, device=device, act=act)
#     130     self.backend = 'torch'
#     132 if isinstance(input_size, int):
#
# File f:\Code\2026\OCReader\basemodel.py:225, in TextDetBase.__init__(self, model_path, device, half, fuse, act)
#     223 def __init__(self, model_path, device='cpu', half=False, fuse=False, act='leaky'):
#     224     super(TextDetBase, self).__init__()
# --> 225     self.blk_det, self.text_seg, self.text_det = get_base_det_models(model_path, device, half, act=act)
#     226     if fuse:
#     227         self.fuse()
#
# File f:\Code\2026\OCReader\basemodel.py:212, in get_base_det_models(model_path, device, half, act)
#     211 def get_base_det_models(model_path, device='cpu', half=False, act='leaky'):
# --> 212     textdetector_dict = torch.load(model_path, map_location=device)
#     213     blk_det = load_yolov5_ckpt(textdetector_dict['blk_det'], map_location=device)
#     214     text_seg = UnetHead(act=act)
#
# File f:\Code\2026\OCReader\.venv\Lib\site-packages\torch\serialization.py:1484, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1481 if "encoding" not in pickle_load_args.keys():
#    1482     pickle_load_args["encoding"] = "utf-8"
# -> 1484 with _open_file_like(f, "rb") as opened_file:
#    1485     if _is_zipfile(opened_file):
#    1486         # The zipfile reader is going to advance the current file position.
#    1487         # If we want to actually tail call to torch.jit.load, we need to
#    1488         # reset back to the original position.
#    1489         orig_position = opened_file.tell()
#
# File f:\Code\2026\OCReader\.venv\Lib\site-packages\torch\serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File f:\Code\2026\OCReader\.venv\Lib\site-packages\torch\serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/comictextdetector.pt'
